# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
sess.run()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-979504f3691d> in <module>()
#       6 import utils
#       7 sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# ----> 8 sess.run()
#
# TypeError: run() missing 1 required positional argument: 'fetches'

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6477 0.1204 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6239 0.1143 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4895 0.1110 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6120 0.1125 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4831 0.1127 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5640 0.1107 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5715 0.1117 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5513 0.1120 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4860 0.1101 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4260 0.1093 sec/batch
# Nearest to years: fifties, biafra, francesc, diffeomorphism, wilbert, intelligently, osage, coals,
# Nearest to called: restarting, withered, disproportionately, dmu, electric, powerpc, condoned, eritrea,
# Nearest to four: sh, monteverdi, pitt, levan, poetically, slots, snout, memoir,
# Nearest to so: kill, computable, boosts, doj, machinery, skier, emotions, height,
# Nearest to from: generalizes, nickleby, pronouncing, da, condamine, plaque, winder, anode,
# Nearest to as: uis, yyyy, rabbinical, intercollegiate, mumps, carmelites, propulsion, courage,
# Nearest to in: and, churchman, swazi, ensured, diphthong, england, satirised, lytton,
# Nearest to one: criminals, thawed, dissociatives, spartacus, tunisian, evolve, montmorency, bureau,
# Nearest to active: gateway, djamena, morgan, farthest, biology, shuster, anaximenes, vellum,
# Nearest to issue: disassembly, cts, alcock, kemal, awg, uruguay, large, outdoor,
# Nearest to pope: bugtraq, alcan, laker, refractory, phallic, levelling, sligo, fate,
# Nearest to versions: hare, isles, ziibi, wielding, poppers, frankly, jus, monetarist,
# Nearest to liberal: direct, nanny, bolshevist, bronchitis, someplace, ample, preterite, cleaveland,
# Nearest to police: plunder, euratom, rangoon, isadore, knock, sidecar, exiles, conjugation,
# Nearest to shown: tms, hinge, shmuel, antiochus, chlorination, ranch, risotto, storied,
# Nearest to joseph: methodius, flanders, ato, proprietors, hobbies, dramas, hebe, fractions,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4459 0.1118 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4379 0.1119 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3418 0.1116 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2447 0.1137 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2056 0.1105 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1525 0.1118 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1144 0.1092 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0589 0.1099 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0123 0.1104 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0137 0.1117 sec/batch
# Nearest to years: fifties, ackermann, intelligently, biafra, classify, normalization, industrial, turns,
# Nearest to called: restarting, electric, lets, eritrea, dmu, disproportionately, withered, polymeric,
# Nearest to four: claim, sh, monteverdi, using, arisen, empire, maintained, slots,
# Nearest to so: kill, machinery, height, resolution, emotions, shared, abuse, boosts,
# Nearest to from: generalizes, dubbed, regardless, variant, dwelling, pronouncing, acknowledged, da,
# Nearest to as: the, is, uis, exceptions, yyyy, incorporate, rabbinical, propulsion,
# Nearest to in: and, england, at, depend, ensured, varied, diphthong, fulfilment,
# Nearest to one: criminals, bureau, evolve, thawed, attributed, inherited, dissociatives, spartacus,
# Nearest to active: gateway, biology, morgan, farthest, djamena, lot, scars, consistent,
# Nearest to issue: large, disassembly, housing, cts, outdoor, god, uruguay, act,
# Nearest to pope: refractory, banned, october, laker, voltage, alcan, bugtraq, fate,
# Nearest to versions: hare, isles, teaming, considered, may, generally, jus, frankly,
# Nearest to liberal: direct, ample, nanny, shared, legend, invited, bronchitis, preterite,
# Nearest to police: curate, occasional, euratom, plunder, conjugation, conceptualization, knock, cmmi,
# Nearest to shown: tms, shmuel, antiochus, region, chlorination, hinge, nazi, meticulous,
# Nearest to joseph: flanders, itv, ato, methodius, hobbies, dramas, proprietors, unfold,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9312 0.1137 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9150 0.1118 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8919 0.1104 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8810 0.1111 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8186 0.1123 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8444 0.1132 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7884 0.1111 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8042 0.1126 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7924 0.1125 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7968 0.1125 sec/batch
# Nearest to years: fifties, classify, normalization, biafra, intelligently, goethe, puzzle, diffeomorphism,
# Nearest to called: electric, restarting, lets, disproportionately, withered, eritrea, powerpc, dmu,
# Nearest to four: memoir, arisen, claim, empire, fabian, mustard, poetically, maintained,
# Nearest to so: height, machinery, kill, resolution, abuse, doj, skier, boosts,
# Nearest to from: generalizes, variant, pronouncing, dwelling, plaque, dubbed, da, deep,
# Nearest to as: the, rabbinical, mumps, situation, propulsion, courage, triangle, ethnic,
# Nearest to in: and, ensured, diphthong, depend, england, introducing, nobles, fulfilment,
# Nearest to one: criminals, bureau, tunisian, six, dissociatives, evolve, spartacus, inherited,
# Nearest to active: gateway, biology, morgan, farthest, consistent, djamena, deteriorated, lot,
# Nearest to issue: large, uruguay, disassembly, cts, outdoor, housing, act, god,
# Nearest to pope: refractory, voltage, sligo, fate, alcan, october, banned, laker,
# Nearest to versions: hare, isles, wielding, measured, jus, flawed, frankly, generally,
# Nearest to liberal: direct, nanny, shared, ample, evoke, invited, reforms, rainbow,
# Nearest to police: euratom, curate, occasional, conjugation, knock, exiles, plunder, conceptualization,
# Nearest to shown: tms, antiochus, shmuel, monarchs, region, virtues, chlorination, hinge,
# Nearest to joseph: itv, flanders, hobbies, dramas, ato, waned, methodius, proprietors,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7623 0.1126 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7589 0.1118 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7043 0.1128 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7262 0.1118 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7396 0.1124 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7007 0.1125 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7126 0.1124 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7385 0.1125 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7173 0.1132 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6753 0.1158 sec/batch
# Nearest to years: fifties, normalization, goethe, biafra, intelligently, relief, classify, peculiarities,
# Nearest to called: restarting, electric, withered, lets, powerpc, condoned, eritrea, disproportionately,
# Nearest to four: memoir, stein, mustard, empire, anna, eight, five, isbn,
# Nearest to so: kill, height, abuse, doj, clumping, ounces, skier, boosts,
# Nearest to from: pronouncing, plaque, tibetan, da, dwelling, generalizes, granules, deep,
# Nearest to as: rabbinical, the, exceptions, situation, triangle, uis, intercollegiate, mumps,
# Nearest to in: and, ensured, introducing, diphthong, fulfilment, churchman, rump, england,
# Nearest to one: six, bureau, nine, tunisian, three, criminals, eight, jean,
# Nearest to active: gateway, biology, farthest, morgan, djamena, consistent, lot, ip,
# Nearest to issue: uruguay, large, disassembly, cts, alcock, act, god, kemal,
# Nearest to pope: sligo, refractory, fate, alcan, october, phallic, banned, hutchinson,
# Nearest to versions: jus, hare, isles, wielding, nica, flawed, measured, evstafiev,
# Nearest to liberal: direct, nanny, reforms, ample, shared, evoke, invited, steadfastly,
# Nearest to police: plunder, knock, curate, euratom, exiles, occasional, conceptualization, sidecar,
# Nearest to shown: tms, antiochus, monarchs, shmuel, hinge, chlorination, openings, deprecated,
# Nearest to joseph: itv, ato, dramas, flanders, methodius, hobbies, waned, sampled,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6721 0.1127 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6678 0.1106 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6141 0.1102 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6402 0.1103 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6292 0.1107 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6414 0.1123 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6100 0.0794 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5606 0.1101 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4758 0.1105 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5039 0.1104 sec/batch
# Nearest to years: fifties, normalization, goethe, biafra, population, diffeomorphism, eighteen, manpower,
# Nearest to called: powerpc, restarting, electric, withered, lets, condoned, zabi, intricacies,
# Nearest to four: five, eight, memoir, stein, three, anna, nine, isbn,
# Nearest to so: height, abuse, doj, ounces, clumping, kill, synthesizers, dire,
# Nearest to from: pronouncing, plaque, dwelling, tibetan, attainable, da, variant, endomorphisms,
# Nearest to as: rabbinical, triangle, the, exceptions, intercollegiate, yyyy, is, mumps,
# Nearest to in: and, fulfilment, introducing, ensured, mahal, rump, impact, at,
# Nearest to one: six, nine, tunisian, three, bureau, eight, john, b,
# Nearest to active: gateway, morgan, djamena, lot, anaximenes, farthest, biology, deteriorated,
# Nearest to issue: uruguay, large, disassembly, alcock, cts, kemal, god, act,
# Nearest to pope: sligo, queen, october, whom, hutchinson, refractory, unabated, fate,
# Nearest to versions: jus, isles, measured, outermost, evstafiev, sleepers, logone, hare,
# Nearest to liberal: direct, reforms, nanny, shared, invited, ample, steadfastly, bolshevist,
# Nearest to police: plunder, euratom, occasional, sidecar, knock, counterpoint, curate, exiles,
# Nearest to shown: tms, hinge, antiochus, shmuel, chlorination, polos, transmitted, openings,
# Nearest to joseph: methodius, itv, ato, dramas, flanders, physiologist, barry, sampled,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5308 0.1115 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5282 0.1102 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4467 0.1105 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5013 0.1099 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4987 0.1107 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4859 0.1114 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4863 0.1117 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3934 0.1106 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4368 0.1110 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4279 0.1110 sec/batch
# Nearest to years: fifties, goethe, normalization, population, eighteen, manpower, biafra, diffeomorphism,
# Nearest to called: restarting, powerpc, electric, lets, intricacies, variation, zabi, disproportionately,
# Nearest to four: three, five, memoir, levan, eight, hempstead, mustard, pitt,
# Nearest to so: clumping, doj, ounces, kill, synthesizers, height, dire, pantheons,
# Nearest to from: dwelling, tibetan, mesopotamian, attainable, endomorphisms, pronouncing, plaque, deep,
# Nearest to as: exceptions, is, yyyy, the, rabbinical, uis, intercollegiate, mumps,
# Nearest to in: and, mahal, introducing, rump, fulfilment, ensured, churchman, impact,
# Nearest to one: six, tunisian, bureau, three, nine, spartacus, dissociatives, zero,
# Nearest to active: gateway, djamena, biology, deteriorated, caspian, metrical, convair, govt,
# Nearest to issue: uruguay, disassembly, cts, god, alcock, large, yeltsin, act,
# Nearest to pope: sligo, queen, whom, october, hutchinson, xxxiii, fate, philippa,
# Nearest to versions: jus, evstafiev, sleepers, isles, hare, logone, poppers, betting,
# Nearest to liberal: reforms, direct, nanny, majority, shared, ministers, ample, cork,
# Nearest to police: plunder, cmmi, euratom, bava, exiles, ocarina, curate, masterpieces,
# Nearest to shown: tms, hinge, antiochus, openings, shmuel, transmitted, chlorination, polos,
# Nearest to joseph: methodius, itv, ato, dramas, physiologist, flanders, waned, barry,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4476 0.1114 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4047 0.1109 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4279 0.1126 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3739 0.1111 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4035 0.1109 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4522 0.1113 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3904 0.1122 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3776 0.1108 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4010 0.1111 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3622 0.1121 sec/batch
# Nearest to years: population, fifties, goethe, manpower, eighteen, diffeomorphism, promenade, babcock,
# Nearest to called: restarting, powerpc, electric, variation, lets, intricacies, zabi, nagy,
# Nearest to four: three, five, eight, levan, zero, memoir, two, isbn,
# Nearest to so: clumping, doj, pantheons, kill, synthesizers, ounces, nurseries, resolution,
# Nearest to from: endomorphisms, attainable, pronouncing, variant, tibetan, dwelling, plaque, shawl,
# Nearest to as: exceptions, is, uis, courage, deeming, triangle, implicit, mumps,
# Nearest to in: and, mahal, churchman, impact, fulfilment, introducing, rump, mansions,
# Nearest to one: three, six, tunisian, bureau, nine, eight, zero, j,
# Nearest to active: gateway, djamena, caspian, convair, biology, anaximenes, lubricants, lot,
# Nearest to issue: disassembly, cts, uruguay, alcock, god, yeltsin, kemal, ecclesiology,
# Nearest to pope: sligo, whom, queen, fate, franks, sons, philippa, levelling,
# Nearest to versions: evstafiev, jus, hare, sleepers, logone, manufacturers, isles, fada,
# Nearest to liberal: reforms, direct, majority, ministers, steadfastly, nanny, warlordism, shared,
# Nearest to police: plunder, arrested, supervision, ecowas, cmmi, euratom, ocarina, bava,
# Nearest to shown: tms, hinge, openings, bce, chlorination, antiochus, reappearance, transmitted,
# Nearest to joseph: methodius, ato, itv, dramas, physiologist, barry, flanders, botanist,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3622 0.1130 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3879 0.1121 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3332 0.1121 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3796 0.1112 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3932 0.1103 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3720 0.1105 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3885 0.1095 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3696 0.1105 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3528 0.1096 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3249 0.1115 sec/batch
# Nearest to years: population, goethe, fifties, manpower, mortality, promenade, eighteen, eleonore,
# Nearest to called: restarting, lets, powerpc, variation, zabi, intricacies, disproportionately, baptize,
# Nearest to four: three, five, eight, zero, two, levan, hempstead, zairian,
# Nearest to so: clumping, ounces, pantheons, kill, nurseries, synthesizers, saluting, indistinguishable,
# Nearest to from: dwelling, tibetan, fragility, endomorphisms, variant, condamine, attainable, pronouncing,
# Nearest to as: exceptions, uis, is, ethnic, implicit, the, deeming, courage,
# Nearest to in: and, mahal, saharan, fulfilment, at, churchman, impact, diphthong,
# Nearest to one: three, six, bureau, tunisian, zero, nine, eight, inherited,
# Nearest to active: gateway, djamena, caspian, convair, lot, deteriorated, massoud, govt,
# Nearest to issue: disassembly, cts, uruguay, alcock, yeltsin, god, kemal, ecclesiology,
# Nearest to pope: sligo, queen, whom, fate, philippa, franks, unabated, leo,
# Nearest to versions: jus, sleepers, directory, evstafiev, logone, manufacturers, fada, lcds,
# Nearest to liberal: reforms, direct, majority, ministers, bolshevist, warlordism, steadfastly, shared,
# Nearest to police: arrested, plunder, ecowas, cmmi, supervision, security, bava, ocarina,
# Nearest to shown: tms, openings, hinge, bce, chlorination, sensitive, transmitted, polos,
# Nearest to joseph: methodius, ato, dramas, itv, botanist, physiologist, flanders, barry,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3571 0.1132 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2717 0.1114 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3736 0.1119 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3953 0.1117 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3961 0.1124 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2837 0.1126 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3116 0.1134 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3277 0.1128 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1973 0.1129 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2879 0.1139 sec/batch
# Nearest to years: population, mortality, female, rate, males, goethe, manpower, promenade,
# Nearest to called: restarting, lets, powerpc, variation, baptize, zabi, shakti, masquerade,
# Nearest to four: five, three, zero, eight, two, levan, hempstead, nine,
# Nearest to so: clumping, pantheons, ounces, nurseries, saluting, indistinguishable, kill, speedily,
# Nearest to from: tibetan, dwelling, variant, condamine, fragility, pronouncing, plaque, native,
# Nearest to as: uis, exceptions, is, deeming, yyyy, implicit, yungay, barnstorming,
# Nearest to in: and, mahal, saharan, at, flashed, impact, rump, universit,
# Nearest to one: six, three, nine, zero, eight, andr, two, bureau,
# Nearest to active: gateway, caspian, djamena, convair, resettlement, massoud, lubricants, deteriorated,
# Nearest to issue: disassembly, alcock, cts, yeltsin, large, ecclesiology, uruguay, kemal,
# Nearest to pope: queen, sligo, whom, philippa, avignon, anastasia, franks, rdoba,
# Nearest to versions: directory, manufacturers, sleepers, evstafiev, jus, logone, lcds, nsf,
# Nearest to liberal: reforms, direct, ministers, steadfastly, majority, shared, party, bolshevist,
# Nearest to police: arrested, euratom, security, plunder, supervision, kyo, cmmi, ocarina,
# Nearest to shown: tms, bce, chlorination, hinge, reappearance, openings, equalled, clickable,
# Nearest to joseph: methodius, physiologist, ato, botanist, flanders, dramas, lecture, itv,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2887 0.1150 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2964 0.1141 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3328 0.0477 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2610 0.1132 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2325 0.1118 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2320 0.1114 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2282 0.1125 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1935 0.1113 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2186 0.1120 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1700 0.1104 sec/batch
# Nearest to years: population, mortality, female, males, rate, promenade, goethe, manpower,
# Nearest to called: restarting, powerpc, lets, the, variation, zabi, shakti, polymeric,
# Nearest to four: five, three, zero, eight, two, levan, easternmost, hempstead,
# Nearest to so: clumping, pantheons, saluting, ounces, kill, doj, nurseries, agglutinative,
# Nearest to from: dwelling, variant, tibetan, about, pronouncing, endomorphisms, plaque, condamine,
# Nearest to as: uis, exceptions, deeming, yungay, is, yyyy, barnstorming, negated,
# Nearest to in: and, at, saharan, impact, mahal, universit, kahane, rump,
# Nearest to one: three, six, nine, zero, eight, bureau, two, tunisian,
# Nearest to active: gateway, caspian, djamena, resettlement, massoud, convair, anaximenes, lubricants,
# Nearest to issue: disassembly, alcock, cts, yeltsin, ecclesiology, large, god, uruguay,
# Nearest to pope: sligo, queen, philippa, avignon, eusebio, whom, rdoba, leo,
# Nearest to versions: manufacturers, directory, lcds, sleepers, evstafiev, logone, porting, jus,
# Nearest to liberal: reforms, direct, ministers, shared, steadfastly, party, majority, bolshevist,
# Nearest to police: arrested, euratom, catalana, security, ocarina, plunder, barracks, cmmi,
# Nearest to shown: tms, openings, chlorination, bce, hinge, equalled, reappearance, antiochus,
# Nearest to joseph: methodius, ato, physiologist, lecture, botanist, dramas, flanders, sociologist,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2561 0.1108 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2123 0.1095 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2543 0.1101 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1104 0.1112 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1639 0.1109 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1767 0.1102 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1677 0.1112 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1917 0.1110 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2056 0.1106 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1580 0.1114 sec/batch
# Nearest to years: population, mortality, rate, males, female, eighteen, goethe, manpower,
# Nearest to called: restarting, lets, the, powerpc, zabi, epimorphism, variation, polymeric,
# Nearest to four: five, three, zero, eight, two, levan, fiscal, ot,
# Nearest to so: clumping, saluting, synthesizers, ounces, pantheons, kill, computable, ils,
# Nearest to from: variant, dwelling, pronouncing, endomorphisms, tibetan, plaque, condamine, about,
# Nearest to as: exceptions, uis, is, yungay, yyyy, most, deeming, kotaka,
# Nearest to in: and, at, impact, mahal, ensured, pancreatitis, shrubbery, uncritical,
# Nearest to one: six, three, zero, nine, eight, two, tunisian, bureau,
# Nearest to active: caspian, gateway, djamena, resettlement, convair, massoud, lubricants, govt,
# Nearest to issue: disassembly, cts, alcock, yeltsin, ecclesiology, god, large, disambiguate,
# Nearest to pope: sligo, queen, avignon, philippa, eusebio, leo, rdoba, whom,
# Nearest to versions: lcds, manufacturers, hare, porting, sleepers, directory, evstafiev, hittite,
# Nearest to liberal: reforms, direct, party, ministers, steadfastly, majority, shared, bolshevist,
# Nearest to police: arrested, euratom, plunder, ocarina, kyo, catalana, supervision, fliers,
# Nearest to shown: tms, bce, openings, chlorination, hinge, equalled, polos, antiochus,
# Nearest to joseph: methodius, lecture, ato, physiologist, flanders, boca, hebe, geta,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1889 0.1118 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2042 0.1119 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1857 0.1120 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1602 0.1122 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1905 0.1120 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2126 0.1135 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1838 0.1126 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1405 0.1139 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1259 0.1141 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1963 0.1134 sec/batch
# Nearest to years: population, rate, mortality, female, males, eighteen, goethe, diffeomorphism,
# Nearest to called: restarting, lets, epimorphism, powerpc, lush, polymeric, zabi, masquerade,
# Nearest to four: five, three, zero, two, eight, nine, fiscal, six,
# Nearest to so: clumping, saluting, marries, ounces, pantheons, matin, speedily, fronti,
# Nearest to from: variant, dwelling, pronouncing, condamine, tibetan, attainable, plaque, about,
# Nearest to as: is, exceptions, uis, yungay, most, yyyy, saratoga, courage,
# Nearest to in: and, at, mahal, impact, universit, ensured, saharan, shrubbery,
# Nearest to one: three, six, nine, zero, eight, two, five, tunisian,
# Nearest to active: gateway, caspian, djamena, ice, convair, resettlement, massoud, deteriorated,
# Nearest to issue: disassembly, yeltsin, ecclesiology, cts, alcock, large, uruguay, awg,
# Nearest to pope: avignon, sligo, queen, eusebio, philippa, leo, whom, orthodoxy,
# Nearest to versions: porting, lcds, manufacturers, hare, sleepers, evstafiev, fada, hittite,
# Nearest to liberal: reforms, party, majority, direct, ministers, steadfastly, bolshevist, partisan,
# Nearest to police: arrested, euratom, ocarina, supervision, plunder, kyo, barracks, catalana,
# Nearest to shown: tms, bce, chlorination, openings, hinge, reappearance, clickable, radially,
# Nearest to joseph: methodius, lecture, physiologist, ato, boca, flanders, dramas, botanist,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1962 0.1148 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1648 0.1125 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1902 0.1122 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1915 0.1124 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1235 0.1127 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1373 0.1128 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1689 0.1103 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1389 0.1099 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1736 0.1097 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1968 0.1099 sec/batch
# Nearest to years: population, mortality, rate, males, eighteen, female, goethe, eleonore,
# Nearest to called: restarting, lavon, masquerade, lets, lush, epimorphism, zabi, powerpc,
# Nearest to four: five, three, zero, eight, two, nine, six, seven,
# Nearest to so: marries, clumping, saluting, ounces, pantheons, dire, speedily, nurseries,
# Nearest to from: condamine, variant, tibetan, dwelling, fragility, pronouncing, plaque, about,
# Nearest to as: exceptions, is, uis, yungay, the, most, ltte, deeming,
# Nearest to in: and, at, mahal, of, universit, recess, saharan, during,
# Nearest to one: six, three, nine, zero, eight, two, five, seven,
# Nearest to active: djamena, gateway, caspian, convair, resettlement, ice, massoud, mtu,
# Nearest to issue: yeltsin, disassembly, large, ecclesiology, alcock, wtoo, uruguay, skeptical,
# Nearest to pope: avignon, sligo, philippa, queen, eusebio, orthodoxy, leo, unabated,
# Nearest to versions: lcds, porting, nsf, manufacturers, hare, hittite, directory, sleepers,
# Nearest to liberal: direct, party, reforms, majority, ministers, shared, bolshevist, steadfastly,
# Nearest to police: arrested, barracks, euratom, civilian, service, security, catalana, cmmi,
# Nearest to shown: bce, tms, openings, chlorination, hinge, equalled, clickable, reappearance,
# Nearest to joseph: methodius, ato, flanders, boca, lecture, physiologist, dramas, itv,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2716 0.1155 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1320 0.1106 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1152 0.1101 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1490 0.1101 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0352 0.1120 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1261 0.1159 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1389 0.1102 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1484 0.1121 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1694 0.0141 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1494 0.1096 sec/batch
# Nearest to years: population, mortality, female, rate, males, migrant, year, eighteen,
# Nearest to called: powerpc, restarting, epimorphism, the, lavon, masquerade, cluster, lets,
# Nearest to four: five, three, zero, two, eight, nine, six, seven,
# Nearest to so: ounces, pantheons, clumping, dire, saluting, indistinguishable, computable, nurseries,
# Nearest to from: variant, pronouncing, tibetan, about, condamine, endomorphisms, native, cen,
# Nearest to as: is, exceptions, uis, yyyy, the, yungay, most, intercollegiate,
# Nearest to in: and, at, universit, mahal, of, recess, haitians, during,
# Nearest to one: three, nine, six, zero, two, eight, five, seven,
# Nearest to active: caspian, gateway, djamena, convair, massoud, gunung, ice, resettlement,
# Nearest to issue: disassembly, yeltsin, large, wtoo, alcock, disambiguate, cts, ecclesiology,
# Nearest to pope: avignon, queen, sligo, philippa, eusebio, phallic, unabated, leo,
# Nearest to versions: porting, manufacturers, lcds, nsf, hittite, graphics, desktop, fada,
# Nearest to liberal: party, direct, shared, steadfastly, reforms, majority, ministers, bolshevist,
# Nearest to police: arrested, barracks, catalana, euratom, kyo, cmmi, civilian, ocarina,
# Nearest to shown: chlorination, bce, tms, openings, equalled, reappearance, hinge, clickable,
# Nearest to joseph: methodius, ato, flanders, boca, physiologist, lecture, thynne, botanist,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0781 0.1142 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0839 0.1105 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0977 0.1101 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0578 0.1091 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0950 0.1080 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0578 0.1087 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0916 0.1083 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1174 0.1102 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1075 0.1089 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0508 0.1090 sec/batch
# Nearest to years: population, mortality, female, year, eighteen, rate, males, migrant,
# Nearest to called: the, epimorphism, powerpc, restarting, polymeric, masquerade, lush, lavon,
# Nearest to four: five, three, zero, two, eight, nine, six, ot,
# Nearest to so: marries, ounces, dire, pantheons, saluting, nurseries, synthesizers, computable,
# Nearest to from: variant, about, pronouncing, condamine, dwelling, tibetan, native, hernando,
# Nearest to as: is, the, exceptions, most, yungay, yyyy, uis, barnstorming,
# Nearest to in: and, at, of, universit, first, recess, during, the,
# Nearest to one: six, three, nine, zero, two, eight, five, interval,
# Nearest to active: caspian, ice, djamena, convair, resettlement, lubricants, gateway, massoud,
# Nearest to issue: disassembly, yeltsin, ecclesiology, god, disambiguate, wtoo, alcock, large,
# Nearest to pope: avignon, sligo, eusebio, queen, unabated, philippa, refractory, leo,
# Nearest to versions: porting, lcds, manufacturers, nsf, hittite, directory, fada, hare,
# Nearest to liberal: party, shared, clinically, ministers, direct, democrat, bolshevist, steadfastly,
# Nearest to police: arrested, catalana, pneumoniae, barracks, kyo, fliers, cmmi, prasutagus,
# Nearest to shown: bce, chlorination, equalled, openings, hinge, tms, reappearance, antiochus,
# Nearest to joseph: methodius, ato, boca, flanders, elblag, mazar, itv, thynne,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0502 0.1102 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0190 0.1091 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0267 0.1101 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0548 0.1089 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0859 0.1087 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0818 0.1094 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0509 0.1090 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1136 0.1090 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0597 0.1096 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0234 0.1092 sec/batch
# Nearest to years: population, mortality, female, rate, year, eighteen, males, migrant,
# Nearest to called: epimorphism, restarting, polymeric, lavon, masquerade, lush, powerpc, the,
# Nearest to four: five, three, zero, two, eight, nine, six, seven,
# Nearest to so: ounces, marries, pantheons, synthesizers, computable, clumping, nurseries, saluting,
# Nearest to from: about, variant, simile, gripped, pronouncing, condamine, fantastically, endomorphisms,
# Nearest to as: is, most, exceptions, yyyy, the, yungay, uis, implicit,
# Nearest to in: and, at, of, first, universit, draws, recess, mahal,
# Nearest to one: three, nine, six, zero, two, eight, five, seven,
# Nearest to active: caspian, ice, djamena, convair, massoud, resettlement, lubricants, gunung,
# Nearest to issue: disassembly, yeltsin, cts, large, ecclesiology, skeptical, wtoo, nonexistence,
# Nearest to pope: avignon, eusebio, sligo, orthodoxy, refractory, unabated, boniface, papal,
# Nearest to versions: lcds, fada, manufacturers, porting, hare, subdivision, hittite, nsf,
# Nearest to liberal: party, clinically, reforms, shared, steadfastly, direct, bolshevist, nnrot,
# Nearest to police: arrested, pneumoniae, kyo, catalana, barracks, naruto, fliers, prasutagus,
# Nearest to shown: bce, chlorination, openings, equalled, tms, hinge, reappearance, radially,
# Nearest to joseph: methodius, boca, ato, elblag, flanders, physiologist, thynne, mazar,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0265 0.1099 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0806 0.1084 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0953 0.1085 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0538 0.1087 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0747 0.1099 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0190 0.1080 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0618 0.1084 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0413 0.1097 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1114 0.1088 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0920 0.1097 sec/batch
# Nearest to years: population, mortality, year, rate, eighteen, female, one, males,
# Nearest to called: epimorphism, lavon, lush, restarting, masquerade, shakti, coordinating, sparking,
# Nearest to four: five, three, zero, two, eight, nine, six, seven,
# Nearest to so: marries, speedily, nurseries, ounces, subordinates, dire, saluting, ils,
# Nearest to from: about, variant, of, simile, condamine, sennar, kanem, fragility,
# Nearest to as: the, most, is, yungay, exceptions, barnstorming, ltte, yyyy,
# Nearest to in: and, of, first, at, universit, the, recess, mahal,
# Nearest to one: three, six, zero, nine, two, five, eight, seven,
# Nearest to active: ice, caspian, djamena, lubricants, convair, mtu, massoud, gunung,
# Nearest to issue: disassembly, yeltsin, large, ecclesiology, uruguay, wtoo, alcock, disambiguate,
# Nearest to pope: avignon, sligo, eusebio, boniface, philippa, orthodoxy, leo, unabated,
# Nearest to versions: manufacturers, lcds, porting, fada, subdivision, directory, logone, hittite,
# Nearest to liberal: party, clinically, shared, bolshevist, steadfastly, nnrot, majority, molloy,
# Nearest to police: arrested, pneumoniae, catalana, kyo, fliers, service, junichiro, security,
# Nearest to shown: bce, chlorination, tms, hinge, equalled, openings, reappearance, kung,
# Nearest to joseph: methodius, elblag, boca, ato, flanders, physiologist, mazar, ignaz,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0472 0.1105 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0292 0.1088 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0520 0.1092 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0674 0.1101 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0407 0.1099 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1166 0.1092 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1313 0.1091 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0700 0.1097 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0065 0.1092 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0784 0.1098 sec/batch
# Nearest to years: mortality, population, year, rate, eighteen, males, female, one,
# Nearest to called: epimorphism, lush, lavon, restarting, masquerade, shakti, coordinating, automorphisms,
# Nearest to four: five, three, zero, two, eight, nine, six, seven,
# Nearest to so: marries, speedily, ounces, saluting, pantheons, dire, nurseries, indistinguishable,
# Nearest to from: about, kaspar, variant, simile, gripped, condamine, of, kanem,
# Nearest to as: the, most, is, exceptions, yungay, implicit, yyyy, gu,
# Nearest to in: and, at, of, first, universit, the, recess, during,
# Nearest to one: three, nine, zero, six, two, eight, five, seven,
# Nearest to active: djamena, caspian, ice, mtu, massoud, convair, lubricants, gunung,
# Nearest to issue: yeltsin, disassembly, ecclesiology, large, alcock, uruguay, wtoo, disambiguate,
# Nearest to pope: avignon, philippa, sligo, refractory, papal, unabated, eusebio, orthodoxy,
# Nearest to versions: fada, manufacturers, porting, subdivision, lcds, logone, directory, cascading,
# Nearest to liberal: party, clinically, nnrot, shared, steadfastly, molloy, reforms, cleaveland,
# Nearest to police: arrested, pneumoniae, barracks, service, naruto, fliers, civilian, catalana,
# Nearest to shown: bce, chlorination, kung, tms, hinge, openings, equalled, larmor,
# Nearest to joseph: methodius, elblag, boca, flanders, archipel, mazar, physiologist, ato,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0019 0.1119 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9981 0.1111 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0214 0.1094 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0126 0.1093 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0642 0.1090 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0449 0.0922 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9923 0.1103 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9779 0.1099 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0427 0.1141 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9646 0.1100 sec/batch
# Nearest to years: mortality, year, population, female, rate, males, eighteen, migrant,
# Nearest to called: epimorphism, lush, masquerade, lavon, the, powerpc, shakti, restarting,
# Nearest to four: five, three, zero, two, eight, nine, six, seven,
# Nearest to so: marries, speedily, ounces, indistinguishable, pantheons, dire, nurseries, computable,
# Nearest to from: about, of, variant, kaspar, condamine, haudenosaunee, gripped, heraklion,
# Nearest to as: the, is, most, exceptions, barnstorming, yyyy, peh, implicit,
# Nearest to in: first, of, at, and, recess, universit, the, during,
# Nearest to one: nine, six, two, three, eight, zero, five, seven,
# Nearest to active: caspian, ice, djamena, massoud, gunung, deteriorated, llobregat, mtu,
# Nearest to issue: disassembly, yeltsin, large, ecclesiology, wtoo, alcock, disambiguate, nonexistence,
# Nearest to pope: avignon, eusebio, padua, refractory, philippa, sligo, papal, wiles,
# Nearest to versions: manufacturers, porting, lcds, fada, logone, maclisp, nfs, ziibi,
# Nearest to liberal: party, clinically, nnrot, molloy, cleaveland, steadfastly, shared, bolshevist,
# Nearest to police: arrested, pneumoniae, naruto, service, barracks, fliers, catalana, mtu,
# Nearest to shown: bce, hinge, equalled, openings, kung, chlorination, tms, reappearance,
# Nearest to joseph: methodius, elblag, boca, flanders, physiologist, ato, mazar, archipel,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9877 0.1109 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9318 0.1103 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0218 0.1109 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0343 0.1098 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0175 0.1099 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0046 0.1091 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8980 0.1098 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9952 0.1091 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9456 0.1090 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9755 0.1090 sec/batch
# Nearest to years: mortality, population, female, year, rate, eighteen, age, seven,
# Nearest to called: epimorphism, lush, the, masquerade, automorphisms, restarting, lavon, astatine,
# Nearest to four: five, three, zero, two, eight, nine, six, seven,
# Nearest to so: marries, ounces, nurseries, computable, speedily, saluting, indistinguishable, synthesizers,
# Nearest to from: about, of, variant, login, three, gripped, the, watts,
# Nearest to as: is, the, most, yungay, yyyy, exceptions, glycoprotein, in,
# Nearest to in: and, first, the, of, at, a, recess, during,
# Nearest to one: nine, six, two, three, zero, eight, five, seven,
# Nearest to active: ice, caspian, djamena, mtu, lubricants, convair, massoud, gunung,
# Nearest to issue: yeltsin, disassembly, large, wtoo, ecclesiology, disambiguate, awg, uruguay,
# Nearest to pope: avignon, eusebio, refractory, padua, unabated, boniface, papal, sligo,
# Nearest to versions: manufacturers, fada, lcds, porting, hare, ziibi, logone, subdivision,
# Nearest to liberal: party, clinically, molloy, nnrot, democrat, bolshevist, moderate, standardise,
# Nearest to police: arrested, pneumoniae, service, naruto, prasutagus, barracks, fliers, sip,
# Nearest to shown: bce, equalled, openings, hinge, kung, chlorination, tms, reappearance,
# Nearest to joseph: methodius, elblag, flanders, boca, mazar, archipel, bamberg, thynne,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9870 0.1114 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0216 0.1107 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9450 0.1103 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0189 0.1101 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0322 0.1097 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9504 0.1107 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9892 0.1100 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9855 0.1108 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9934 0.1118 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9966 0.1097 sec/batch
# Nearest to years: mortality, population, year, eighteen, female, rate, age, goethe,
# Nearest to called: epimorphism, the, lush, automorphisms, masquerade, lavon, astatine, amigaone,
# Nearest to four: five, zero, three, two, eight, nine, six, seven,
# Nearest to so: indistinguishable, computable, nurseries, marries, ounces, matin, speedily, synthesizers,
# Nearest to from: of, about, who, simile, gripped, zoroaster, kaspar, variant,
# Nearest to as: is, the, most, implicit, yungay, exceptions, meso, glycoprotein,
# Nearest to in: of, first, the, and, at, universit, recess, a,
# Nearest to one: nine, six, eight, two, zero, three, five, seven,
# Nearest to active: ice, caspian, mtu, djamena, massoud, lubricants, convair, llobregat,
# Nearest to issue: yeltsin, disassembly, large, ecclesiology, wtoo, nonexistence, cts, uruguay,
# Nearest to pope: avignon, eusebio, boniface, pius, padua, papal, refractory, unabated,
# Nearest to versions: manufacturers, fada, lcds, porting, hare, subdivision, maclisp, logone,
# Nearest to liberal: party, clinically, democrat, molloy, bolshevist, nnrot, moderate, reforms,
# Nearest to police: arrested, pneumoniae, naruto, barracks, service, criminal, fliers, prasutagus,
# Nearest to shown: bce, kung, equalled, openings, hinge, clickable, risotto, chlorination,
# Nearest to joseph: methodius, elblag, boca, flanders, physiologist, archipel, mazar, leonhart,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0147 0.1103 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9823 0.1103 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9913 0.1108 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0269 0.1093 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0230 0.1107 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0140 0.1109 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9977 0.1112 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9557 0.1114 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9549 0.1106 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0302 0.1109 sec/batch
# Nearest to years: mortality, population, year, eighteen, female, rate, age, seven,
# Nearest to called: the, epimorphism, lush, lavon, coordinating, communities, automorphisms, masquerade,
# Nearest to four: five, zero, three, two, eight, nine, six, seven,
# Nearest to so: indistinguishable, marries, speedily, computable, ounces, nurseries, matin, afer,
# Nearest to from: of, the, about, who, to, kaspar, and, khosrau,
# Nearest to as: the, is, most, in, implicit, exceptions, yungay, and,
# Nearest to in: of, and, the, first, at, recess, universit, as,
# Nearest to one: nine, six, two, zero, three, five, eight, seven,
# Nearest to active: ice, caspian, mtu, djamena, lubricants, convair, llobregat, massoud,
# Nearest to issue: yeltsin, disassembly, large, ecclesiology, nonexistence, wtoo, disambiguate, uruguay,
# Nearest to pope: avignon, eusebio, pius, unabated, papal, padua, philippa, boniface,
# Nearest to versions: manufacturers, fada, lcds, porting, subdivision, nfs, nsf, maclisp,
# Nearest to liberal: party, molloy, moderate, clinically, bolshevist, nnrot, reforms, shared,
# Nearest to police: arrested, pneumoniae, service, barracks, criminal, civilian, mtu, naruto,
# Nearest to shown: bce, kung, equalled, hinge, openings, tms, risotto, clickable,
# Nearest to joseph: methodius, elblag, boca, flanders, mazar, archipel, physiologist, geta,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9470 0.1127 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0879 0.1104 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0117 0.1115 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0601 0.1114 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9437 0.1102 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9469 0.1116 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 4.0104 0.1122 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.8973 0.1109 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9918 0.1110 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9856 0.1119 sec/batch
# Nearest to years: mortality, population, year, rate, female, age, eighteen, migrant,
# Nearest to called: epimorphism, automorphisms, the, powerpc, lush, amigaone, masquerade, astatine,
# Nearest to four: five, zero, three, two, eight, nine, six, seven,
# Nearest to so: indistinguishable, computable, ounces, marries, speedily, pantheons, matin, afer,
# Nearest to from: of, about, the, to, who, variant, and, kaspar,
# Nearest to as: the, is, in, most, implicit, and, a, exceptions,
# Nearest to in: and, of, the, first, a, at, as, s,
# Nearest to one: nine, six, two, zero, three, eight, five, seven,
# Nearest to active: ice, caspian, massoud, navajo, gunung, djamena, llobregat, mtu,
# Nearest to issue: yeltsin, disassembly, large, ecclesiology, wtoo, uruguay, alcock, nf,
# ...
# Nearest to joseph: methodius, archipel, thynne, nitrate, elblag, physiologist, boca, mazar,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8900 0.1118 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7535 0.1120 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8526 0.1122 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8437 0.1118 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7682 0.1148 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8542 0.1129 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8876 0.1116 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8565 0.1097 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8463 0.1106 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9211 0.1095 sec/batch
# Nearest to years: year, eighteen, female, seven, mortality, population, five, age,
# Nearest to called: the, epimorphism, automorphisms, an, with, notably, is, s,
# Nearest to four: five, three, zero, two, eight, six, nine, seven,
# Nearest to so: naaman, starches, to, indistinguishable, afer, computable, speedily, firmer,
# Nearest to from: of, the, and, who, for, to, in, three,
# Nearest to as: the, is, and, a, in, of, also, such,
# Nearest to in: the, and, of, a, first, s, which, at,
# Nearest to one: nine, two, six, eight, three, five, zero, seven,
# Nearest to active: navajo, ice, caspian, householder, practically, ozzie, mouthwash, mtu,
# Nearest to issue: nf, counterpart, rescuing, discussed, yeltsin, casc, plains, continual,
# Nearest to pope: avignon, boniface, pius, papal, leo, xi, padua, refractory,
# Nearest to versions: version, kane, sergei, outermost, lcds, molality, fada, translations,
# Nearest to liberal: democrat, nnrot, molloy, party, moderate, clinically, debates, musicbrainz,
# Nearest to police: arrested, pneumoniae, latvijas, pertaining, convict, robbery, catalana, criminal,
# Nearest to shown: kain, equalled, bce, blankets, cb, ibc, appears, risotto,
# Nearest to joseph: methodius, archipel, thynne, nitrate, physiologist, boca, elblag, mazar,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8224 0.1105 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8282 0.1095 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8605 0.1099 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8603 0.1109 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8515 0.1114 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8664 0.1093 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8242 0.1105 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8548 0.1166 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8827 0.1094 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8620 0.1141 sec/batch
# Nearest to years: year, seven, female, eighteen, five, over, one, age,
# Nearest to called: the, epimorphism, automorphisms, notably, an, is, with, kingdom,
# Nearest to four: five, zero, three, two, six, nine, eight, seven,
# Nearest to so: to, indistinguishable, starches, afer, that, speedily, naaman, kurt,
# Nearest to from: of, the, and, to, in, for, about, one,
# Nearest to as: the, and, a, is, in, of, also, most,
# Nearest to in: the, of, and, a, which, first, at, as,
# Nearest to one: nine, two, six, three, eight, zero, five, seven,
# Nearest to active: navajo, ice, practically, caspian, householder, ozzie, quicker, methodologies,
# Nearest to issue: nf, counterpart, casc, continual, discussed, mirth, reappraisal, yeltsin,
# Nearest to pope: avignon, boniface, pius, papal, leo, padua, xi, eusebio,
# Nearest to versions: version, outermost, kane, fada, lcds, sergei, translations, nsf,
# Nearest to liberal: nnrot, molloy, democrat, party, moderate, clinically, musicbrainz, watered,
# Nearest to police: arrested, pneumoniae, latvijas, pertaining, robbery, catalana, fliers, civilian,
# Nearest to shown: kain, ibc, bce, equalled, appears, blankets, cb, horoscope,
# Nearest to joseph: methodius, archipel, nitrate, thynne, boca, physiologist, dubious, mazar,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8890 0.1121 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8806 0.1134 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8294 0.1182 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8568 0.1251 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8706 0.1160 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8617 0.1110 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9479 0.1119 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9345 0.1108 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9309 0.1099 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8119 0.1099 sec/batch
# Nearest to years: year, female, seven, over, five, eighteen, one, mortality,
# Nearest to called: epimorphism, automorphisms, the, an, notably, kingdom, homotopy, such,
# Nearest to four: five, zero, three, two, nine, eight, six, one,
# Nearest to so: indistinguishable, naaman, speedily, afer, to, that, starches, kurt,
# Nearest to from: the, of, and, in, for, to, one, three,
# Nearest to as: the, and, a, is, in, also, of, such,
# Nearest to in: the, and, of, a, which, during, first, as,
# Nearest to one: nine, two, three, six, zero, eight, five, seven,
# Nearest to active: navajo, ice, householder, practically, ozzie, caspian, unnumbered, optimistic,
# Nearest to issue: nf, mirth, discussed, casc, counterpart, commissary, yeltsin, continual,
# Nearest to pope: avignon, boniface, leo, pius, papal, xi, padua, ordinis,
# Nearest to versions: version, outermost, kane, fada, nsf, sergei, translations, lcds,
# Nearest to liberal: nnrot, molloy, democrat, party, moderate, watered, clinically, musicbrainz,
# Nearest to police: latvijas, arrested, pneumoniae, pertaining, robbery, civilian, catalana, barracks,
# Nearest to shown: ibc, kain, bce, horoscope, equalled, parthia, appears, cb,
# Nearest to joseph: methodius, archipel, thynne, nitrate, boca, him, physiologist, cowdery,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7981 0.1106 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8526 0.1086 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7978 0.1085 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8766 0.1097 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8561 0.1093 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8378 0.1263 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9080 0.0451 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8370 0.1160 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8480 0.1150 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8263 0.1088 sec/batch
# Nearest to years: year, female, eighteen, mortality, five, over, seven, age,
# Nearest to called: the, epimorphism, automorphisms, an, such, with, notably, source,
# Nearest to four: five, two, zero, three, nine, eight, six, one,
# Nearest to so: to, indistinguishable, starches, speedily, naaman, afer, this, but,
# Nearest to from: the, of, and, to, in, for, following, who,
# Nearest to as: the, a, and, in, is, of, also, such,
# Nearest to in: the, of, and, a, which, first, at, as,
# Nearest to one: nine, two, eight, six, three, five, seven, zero,
# Nearest to active: navajo, ice, householder, caspian, unnumbered, practically, musicum, mouthwash,
# Nearest to issue: nf, mirth, discussed, casc, continual, disassembly, irda, yeltsin,
# Nearest to pope: avignon, boniface, pius, leo, papal, xi, padua, ordinis,
# Nearest to versions: version, outermost, kane, hpc, lcds, fada, nsf, manufacturers,
# Nearest to liberal: nnrot, democrat, molloy, party, clinically, watered, moderate, debates,
# Nearest to police: latvijas, arrested, pneumoniae, officers, pertaining, civilian, catalana, bird,
# Nearest to shown: ibc, kain, bce, blankets, horoscope, equalled, appears, leeson,
# Nearest to joseph: methodius, archipel, thynne, physiologist, boca, mazar, cowdery, nitrate,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8414 0.1108 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8093 0.1084 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8403 0.1117 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7679 0.1116 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8471 0.1092 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8303 0.1095 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8854 0.1092 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7438 0.1100 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7762 0.1106 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8296 0.1112 sec/batch
# Nearest to years: female, eighteen, over, year, five, seven, age, mortality,
# Nearest to called: the, an, epimorphism, with, such, automorphisms, is, s,
# Nearest to four: five, zero, three, two, six, eight, nine, one,
# Nearest to so: to, this, starches, naaman, will, but, with, indistinguishable,
# Nearest to from: of, the, and, in, for, to, three, one,
# Nearest to as: the, a, and, is, also, in, of, such,
# Nearest to in: the, of, and, a, which, first, as, also,
# Nearest to one: nine, two, six, zero, three, eight, five, seven,
# Nearest to active: navajo, ice, caspian, householder, practically, methodologies, mouthwash, quicker,
# Nearest to issue: nf, discussed, continual, canadian, yeltsin, wtoo, commissary, casc,
# Nearest to pope: avignon, boniface, pius, leo, papal, xi, sacramental, ordinis,
# Nearest to versions: version, kane, translations, sergei, outermost, fada, nsf, lcds,
# Nearest to liberal: democrat, molloy, party, nnrot, moderate, watered, clinically, musicbrainz,
# Nearest to police: latvijas, pneumoniae, arrested, pertaining, officers, catalana, bird, civilian,
# Nearest to shown: ibc, bce, kain, appears, blankets, is, equalled, cb,
# Nearest to joseph: methodius, archipel, thynne, mazar, cowdery, nitrate, physiologist, boca,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7295 0.1098 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8206 0.1088 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8485 0.1094 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8079 0.1101 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8136 0.1091 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8741 0.1100 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8592 0.1090 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8258 0.1095 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8207 0.1093 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8511 0.1097 sec/batch
# Nearest to years: female, eighteen, year, seven, over, age, five, mortality,
# Nearest to called: the, an, epimorphism, with, is, automorphisms, s, such,
# Nearest to four: five, zero, three, two, six, eight, nine, one,
# Nearest to so: starches, to, but, afer, naaman, will, this, indistinguishable,
# Nearest to from: of, the, and, for, to, in, who, which,
# Nearest to as: the, a, is, and, also, in, of, such,
# Nearest to in: the, of, and, a, which, first, s, is,
# Nearest to one: nine, two, six, eight, three, zero, five, seven,
# Nearest to active: navajo, ice, caspian, householder, practically, mouthwash, musicum, quicker,
# Nearest to issue: nf, discussed, continual, frustration, squeezes, canadian, disassembly, irda,
# Nearest to pope: avignon, boniface, pius, leo, papal, xi, ordinis, sacramental,
# Nearest to versions: version, kane, translations, fada, nsf, outermost, sergei, flakes,
# Nearest to liberal: democrat, nnrot, party, molloy, moderate, musicbrainz, clinically, watered,
# Nearest to police: arrested, pneumoniae, latvijas, officers, civilian, pertaining, catalana, robbery,
# Nearest to shown: kain, ibc, cb, leeson, bce, equalled, blankets, hawthorn,
# Nearest to joseph: methodius, thynne, archipel, boca, physiologist, dubious, mmend, mazar,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8798 0.1108 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8337 0.1104 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8013 0.1130 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8763 0.1090 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8296 0.1084 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8419 0.1100 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8505 0.1098 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8520 0.1131 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8245 0.1102 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8165 0.1093 sec/batch
# Nearest to years: seven, year, five, female, over, age, eighteen, one,
# Nearest to called: the, an, with, epimorphism, is, in, are, and,
# Nearest to four: five, three, zero, two, six, nine, eight, one,
# Nearest to so: to, that, but, starches, this, with, afer, will,
# Nearest to from: the, of, and, for, to, in, which, on,
# Nearest to as: the, a, is, and, in, also, of, such,
# Nearest to in: the, and, of, a, which, as, also, first,
# Nearest to one: nine, two, six, three, eight, seven, five, zero,
# Nearest to active: navajo, ice, householder, caspian, mouthwash, practically, musicum, quicker,
# Nearest to issue: discussed, continual, nf, frustration, canadian, lagrangian, yeltsin, mccheese,
# Nearest to pope: avignon, boniface, leo, pius, xi, papal, ordinis, unabated,
# Nearest to versions: version, nsf, kane, translations, outermost, fada, sergei, flakes,
# Nearest to liberal: democrat, nnrot, moderate, molloy, party, watered, musicbrainz, clinically,
# Nearest to police: pneumoniae, latvijas, arrested, officers, catalana, civilian, robbery, pertaining,
# Nearest to shown: ibc, kain, cb, bce, leeson, appears, equalled, horoscope,
# Nearest to joseph: methodius, thynne, archipel, boca, dubious, mmend, cowdery, flanders,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8376 0.1093 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8535 0.1090 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8852 0.1088 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9347 0.1090 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8941 0.1088 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8449 0.1084 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7765 0.1120 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8513 0.1114 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7258 0.1098 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8448 0.1135 sec/batch
# Nearest to years: year, female, over, five, seven, eighteen, age, mortality,
# Nearest to called: the, an, epimorphism, automorphisms, with, is, notably, such,
# Nearest to four: five, three, zero, two, nine, eight, six, one,
# Nearest to so: this, but, to, that, afer, find, indistinguishable, starches,
# Nearest to from: the, of, and, for, to, in, is, which,
# Nearest to as: the, and, a, in, also, is, of, such,
# Nearest to in: the, and, of, a, as, which, s, also,
# Nearest to one: nine, two, six, eight, three, five, seven, zero,
# Nearest to active: navajo, ice, householder, caspian, mouthwash, practically, musicum, formed,
# Nearest to issue: discussed, nf, continual, frustration, disassembly, mccheese, commissary, mirth,
# Nearest to pope: avignon, boniface, pius, leo, xi, papal, ordinis, refractory,
# Nearest to versions: version, kane, nsf, translations, outermost, fada, sergei, symmetric,
# Nearest to liberal: democrat, nnrot, moderate, molloy, musicbrainz, watered, party, clinically,
# Nearest to police: arrested, latvijas, pneumoniae, officers, robbery, civilian, mtu, barracks,
# Nearest to shown: ibc, is, cb, leeson, been, equalled, bce, appears,
# Nearest to joseph: methodius, archipel, thynne, dubious, mmend, boca, cowdery, hout,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8395 0.1199 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8324 0.1113 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
